# %% [markdown]
# # Q.1

# %% [markdown]
# Matplotlib is an amazing visualization library in Python for 2D plots of arrays. Matplotlib is a multi-platform data visualization library built on NumPy arrays and designed to work with the broader SciPy stack.Although it has its origins in emulating the MATLAB graphics commands, it is independent of MATLAB.
#
# It is used for  2D plotting of data which produces good quality figures useful for understanding the data, analysis of data ,data visualization and finding correlations with the data.
#
# Five plots that can be plotted using the Pyplot module of Matplotlib are as:
# - Scatter Plot
# - Bar Plot
# - Line Plot
# - Box Plot
# - Histogram

# %% [markdown]
# # Q.2

# %% [markdown]
# A scatter plot is a set of points that represents the values obtained for two different variables plotted on a horizontal and vertical axes.

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Data Plot")
plt.show()

# %% [markdown]
# # Q.3

# %% [markdown]
# subplot() is used to divide the given figure into rectangular panes that are numbered row-wise.subplot( m , n , p ) divides the current figure into an m -by- n grid and creates axes in the position specified by p

# %%
import numpy as np
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2,2,1)
plt.plot(x, y)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2,2,2)
plt.plot(x, y)
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,2,3)
plt.plot(x, y)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,4)
plt.plot(x, y)

# %% [markdown]
# # Q.4

# %% [markdown]
# A bar plot is a plot that presents categorical data with rectangular bars with lengths proportional to the counts that they represent.
#
# It is used to represent the frequency distribution of categorical variables and makes it easy to compare sets of data between different groups.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Q.5

# %% [markdown]
# Boxplots are a measure of how well distributed the data in a data set is. It divides the data set into three quartiles. A box plot consists of a box that spans the first quartile (Q1) to the third quartile (Q3) of the data, with a line at the median (Q2). The distance between the first and third quartiles is called the interquartile range (IQR), and any data points that fall outside of 1.5 times the IQR are considered outliers and are represented as points outside of the box.
#
# It is used to show distributions of numeric data values, especially when you want to compare them between multiple groups.It is used to plot for numerical vs categorical variables.
#
# Box plots are useful for identifying:
#
# - Skewness and outliers in a dataset
# - Differences in distribution and spread between multiple datasets
# - The central tendency of a dataset

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.boxplot([box1, box2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23118b84070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23118b84610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23118cf5d60>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x23118b84bb0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x23118b84e80>,
# ...
#  'means': []}
